# %% [markdown]
# # Probability

# %% [markdown]
# ## Challenge 1
# There is a box with 10 white balls, 12 red balls and 8 black balls. Calculate the probability of:
# * Taking a white ball out.
# * Taking a white ball on first extraction and a black ball out on second extraction without replacing the first one.
# * Taking a white ball on first extraction and a black ball out on second extraction replacing the first one.
# * Taking 3 balls and them being all different colours.

# %%
# YOUR CODE HERE
white = 10
red = 12
black = 8
total = white + red + black

# %%
# Taking a white ball out
white_out = white/total
print(f" The probability of taking a white ball out is: {white_out * 100:.2f}%")
# Out:
#  The probability of taking a white ball out is: 33.33%

# %%
#Taking a white ball on first extraction and a black ball out on second extraction without replacing the first one.
white_1=white/total
black_2= black/(total-1)
combined_wr = white_1*black_2
print(f" The probability of taking a white ball on first extraction and a black ball out on second extraction without replacing the first one: {combined_wr * 100:.2f}%")
# Out:
#  The probability of taking a white ball on first extraction and a black ball out on second extraction without replacing the first one: 9.20%

# %%
#Taking a white ball on first extraction and a black ball out on second extraction replacing the first one.
white_1
black_r_replaced = black / total
combined_wr_replaced = white_1*black_r_replaced
print(f" The probability of taking a white ball on first extraction and a black ball out on second extraction replacing the first one: {combined_wr_replaced * 100:.2f}%")
# Out:
#  The probability of taking a white ball on first extraction and a black ball out on second extraction replacing the first one: 8.89%

# %%
#Taking 3 balls and them being all different colours.
fav_cases = white * black * red
tot_cases = (30*29*28)/6        #ways of choosing 3 balls out of the total 30 without replacement       6=3!
probability = fav_cases/tot_cases
+
# Out:
#  The probability of taking 3 balls and them being all different colours: 23.65%

# %% [markdown]
# ## Challenge 2
#
# You want to go on picnic on Saturday. You hate rain, and would know to plan your weekend. To help you make a decision, you gather the following data about rainy days:
#
# * 40% of all days are cloudy.
# * About 50% of cloudy days are rainy.
# * About 20% of non-cloudy days are rainy.
#
# What is the chance of rain during next Saturday?

# %%
# YOUR CODE HERE
cloudy = 0.4
non_cloudy = 1- cloudy
rainy1 = 0.5*cloudy
rainy2 = 0.2*non_cloudy

# %%
#What is the chance of rain during next Saturday?
sat_rain = rainy1+rainy2
print(f" The chance of rain during next Saturday is: {sat_rain * 100:.2f}%")
# Out:
#  The chance of rain during next Saturday is: 32.00%

# %% [markdown]
# ## Challenge 3
#
# A and B are events of a probability such that $P(A) = 0.3$, $P(B) = 0.6$ and $P(A \cap B) = 0.1$
#
# Which of the following statements are true?
# **HINT: draw a big Venn Diagram by your side**
# * $P(\overline{A}) = 0.7$
# * $P(A \cup B) = 0.6$
# * $P(A \cap \overline{B}) = 0.2$
# * $P(A \cup \overline{A}) = 1$
# * $P(A \cap (B \cup \overline{B})) = 0.4$
# * $P(\overline{A} \cap \overline{B}) = 0.3$
# * $P(\overline{A \cap B}) = 0.9$

# %%
# YOUR CODE HERE
pa=0.3
pb=0.6
panb=0.1
total = 1

# %%
pa1=0.7
(total - pa) == pa1
# Out:
# True

# %%
paub=0.6
(pa+pb-panb) == paub
#The answer is 0.8
# Out:
# False

# %%
panb1=0.2
round(pa - panb,2) == panb1
# Out:
# True

# %%
paua1=1
pa+pa1 == paua1
# Out:
# True

# %%
panbub1 = 0.4
pb1 = 1- pb
pbub1 = pb1 + pb
panbub1 == pa * pbub1
#the answer is 0.3
# Out:
# False

# %%
pa1nb1 = 0.3
1 - paub == pa1nb1
#the answer is 0.2
# Out:
# False

# %%
p1anb = 0.9
1 - panb == p1anb
# Out:
# True

# %% [markdown]
# ## Challenge 4
#
#  * If someone flies to China, the probability of getting Covid is 1%
#  * If someone flies to Italy, the probability of getting Covid is 20%
#
# I roll 1 dice with numbers 1, 2, 3, 4, 5, 6:
#  * If 1: I fly to Italy
#  * If not 1: I fly to China
#
# During my trip, I got Covid. What is the probability that I flew to China?

# %%
# YOUR CODE HERE
italy_fly = 1/6
china_fly = 5/6
china_cov=0.01
italy_cov=0.2

# %%
#Total probability of getting Covid
prob_cov= china_cov*china_fly + italy_cov*italy_fly
prob_cov
# Out:
# 0.041666666666666664

# %%
#Probability of having flyed to China given that got Covid
china_fly_cov = (china_cov*china_fly)/prob_cov
print(f" The probability of having flyed to China given that got Covid is: {china_fly_cov * 100:.2f}%")
# Out:
#  The probability of having flyed to China given that got Covid is: 20.00%

# %% [markdown]
# ## BONUS
#
# You roll 2 dice. What is the probability that the sum of the numbers is 7? And 8? And 9? Then simulate 10000 times and draw a countplot.

# %% [markdown]
# your explanation here

# %%
# YOUR CODE HERE
comb_total = 36          #there are 36 different posibilities of combinatios when rolling 2 dice
comb_7 = 6                  # there are 6 combinations of rolling a 7: 1+6,2+5,3+4,4+3,5+2,6+1
comb_8 = 5                  # there are 5 combinations of rolling a 8: 2+6,3+5,4+4,5+3,6+2
comb_9 = 4                  # there are 4 combinations of rolling a 9: 3+6,4+5,5+4,6+3

# %%
prob_7 = comb_7/ comb_total
print(f" The probability of rolling two six-sided dice and rolling a 7 is: {prob_7 * 100:.2f}%")
# Out:
#  The probability of rolling two six-sided dice and rolling a 7 is: 16.67%

# %%
prob_8 = comb_8/ comb_total
print(f" The probability of rolling two six-sided dice and rolling a 8 is: {prob_8 * 100:.2f}%")
# Out:
#  The probability of rolling two six-sided dice and rolling a 8 is: 13.89%

# %%
prob_9 = comb_9/ comb_total
print(f" The probability of rolling two six-sided dice and rolling a 8 is: {prob_9 * 100:.2f}%")
# Out:
#  The probability of rolling two six-sided dice and rolling a 8 is: 11.11%

# %%
#Simulation & Visualization
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
counts = [0] * 13       #make a list of zeros, to store the results from 0 to 12
simulations = 10000

for _ in range(simulations):
    d1 = random.randint(1,6)
    d2 = random.randint(1,6)
    s = d1+d2
    counts[s] += 1          # add 1 to the count of that sum in the list

# %%
sevens = counts[7] / simulations
eights = counts[8] / simulations
nines = counts[9]   / simulations

print(f" The probability after rolling {simulations} times two six-sided dice of rolling a 7 is: {sevens * 100:.2f}%")
print(f" The probability after rolling {simulations} times two six-sided dice of rolling a 8 is: {eights * 100:.2f}%")
print(f" The probability after rolling {simulations} times two six-sided dice of rolling a 9 is: {nines * 100:.2f}%")
# Out:
#  The probability after rolling 10000 times two six-sided dice of rolling a 7 is: 16.23%
#  The probability after rolling 10000 times two six-sided dice of rolling a 8 is: 14.10%
#  The probability after rolling 10000 times two six-sided dice of rolling a 9 is: 10.87%

# %%
sums = list(range(2, 13))                       #Store the range as a list
frequencies = [counts[s] for s in sums]         #Check de total number of times each result was rolled

plt.figure(figsize=(12,5))
plt.bar(sums, frequencies)
plt.title("Simulation of Dice Sums (10000 rolls)")
plt.xlabel("Sum of dice")
plt.ylabel("Count")
plt.tight_layout()
plt.show()
